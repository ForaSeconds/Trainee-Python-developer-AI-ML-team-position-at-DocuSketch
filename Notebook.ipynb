# %%
from main import DrawingPlots
from IPython.display import Image, display

json_file = "deviation.json"

drawing = DrawingPlots(json_file)
new_list = drawing.draw_plots()

for path in new_list:
    display(Image(filename=path))
# Out:
# Удаляем пробелы из названий столбцов
# Имеющиеся столбцы: ['name', 'gt_corners', 'rb_corners', 'mean', 'max', 'min', 'floor_mean', 'floor_max', 'floor_min', 'ceiling_mean', 'ceiling_max', 'ceiling_min']
# Столбцы найдены. Создаю график...
# График построен.
